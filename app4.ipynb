# %% [markdown]
# 左のファイルの領域にapp.py、value_shap_Roberta.py、check_text_lengs.py、RoBERTa.ckptの4つをドラッグ&ドロップしていただき、下のセルを実行すると起動できます。

# %%
#ここで使うものをinstallしておく
# !pip install --upgrade streamlit
# !pip install plotly
# !pip install torch torchvision
# !pip install pytorch-lightning
# !pip install transformers
# !pip install pyngrok
# !pip install shap
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 105.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 122.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 8.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 113.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 82.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 64.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 19.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.9 MB/s eta 0:00:00
# ...

# %% [markdown]
# pyファイル2つおよびckptファイルをアップロードしている状態で以下のセルを実行するとngrokが実行されリンクが生成されます。このとき、3行目にあるトークンはngrokに登録することで取得できます。
# 以下、トークンの取得手順を記載します。
#
#
# 1.   https://ngrok.com/ にアクセスする
# 2.   sign upより新規登録を行う(githubまたはGoogleのアカウントで可能)
# 3.   登録完了後、左上にある"Your Authtoken"をクリックし、画面上部の伏字になっている文字列を下のコード内に入力する

# %%
from pyngrok import ngrok,conf

token = "トークンを入力してください"
# !pkill -f streamlit
# !streamlit run app.py --server.port 8501 --server.maxUploadSize 1 &>/dev/null &
# !pgrep streamlit

from pyngrok import ngrok

# !pkill ngrok

ngrok.set_auth_token(token)

#Streamlitが使用するデフォルトのポート番号8501を明示的に指定
public_url = ngrok.connect("8501").public_url
def convert_http_to_https(url):
    # urlの先頭がhttpだったらhttpsに変更
    if url.startswith("http://"):
        # 1は置換する回数(1を指定することで、元のURL内で最初に見つかった "http://" の部分だけを "https://" に置き換え、他の "http://" は変更されない。)
        url = url.replace("http://", "https://", 1)
    return url
print(convert_http_to_https(public_url))
# Out:
# 2452
# https://722b-34-143-202-228.ngrok-free.app

# %% [markdown]
# ↑ここにurlが生成されます。
# 数字が1行とurlが出力されていれば正しく生成できています。
# そうでない場合、再度実行ボタンを押してください。
